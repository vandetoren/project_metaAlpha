# %%
# Descarga datos Ibex35
import pandas as pd
import yfinance as yf
from yahoofinancials import YahooFinancials
import matplotlib.pyplot as plt

# %%
symbols_list = pd.read_csv('ibex_symbols.csv')
df_0 = yf.download(symbols_list.symbol[0])
df_1 = yf.download(symbols_list.symbol[1])
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
import ta
tsi_0 = ta.momentum.tsi(df_0.Close)
tsi_1 = ta.momentum.tsi(df_1.Close)
